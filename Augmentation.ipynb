# %%
# !pip install nlpaug
# Out:
# Collecting nlpaug
#   Cache entry deserialization failed, entry ignored
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/e9/6d/47d8f50378b0b1edca8f98dc1628420870e076b685214409c6c88caced64/nlpaug-0.0.13.3-py3-none-any.whl (96kB)
#     100% |████████████████████████████████| 102kB 220kB/s a 0:00:01
# Installing collected packages: nlpaug
# Successfully installed nlpaug-0.0.13.3
# You are using pip version 9.0.1, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import os
os.environ["DATA_DIR"]='../datasets/IEMOCAP_CUTTED'

# %%
import nlpaug
nlpaug.__version__
# Out:
# '0.0.13.3'

# %%
import nlpaug.augmenter.audio as naa

#from nlpaug.util.visual import VisualWave

# %%
import librosa
import librosa.display as librosa_display
import matplotlib.pyplot as plt

# %%
file_path = os.environ.get("DATA_DIR") + '/Ses01F_impro01_F000.wav'
data, sr = librosa.load(file_path)

# %%
ipd.Audio(data, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### crop

# %%
aug = naa.CropAug(sampling_rate=sr)
augmented_data = aug.augment(data)

librosa_display.waveplot(augmented_data, sr=sr, alpha=0.5)
librosa_display.waveplot(data, sr=sr, color='r', alpha=0.25)

plt.tight_layout()
plt.show()

# %%
import IPython.display as ipd

# %%
ipd.Audio(augmented_data, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Loudness

# %%
aug = naa.LoudnessAug(loudness_factor=(2, 5))
augmented_data = aug.augment(data)

librosa_display.waveplot(augmented_data, sr=sr, alpha=0.25)
librosa_display.waveplot(data, sr=sr, color='r', alpha=0.5)

plt.tight_layout()
plt.show()
# Out:
# Warning: loudness_factor will be removed after 0.0.12 release. Change to use factor

# %%
ipd.Audio(augmented_data, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### mask

# %%
aug = naa.MaskAug(sampling_rate=sr, mask_with_noise=False)
augmented_data = aug.augment(data)

librosa_display.waveplot(data, sr=sr, alpha=0.5)
librosa_display.waveplot(augmented_data, sr=sr, color='r', alpha=0.25)

plt.tight_layout()
plt.show()

# %%
ipd.Audio(augmented_data, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Noise

# %%
aug = naa.NoiseAug(noise_factor=0.03)
augmented_data = aug.augment(data)

librosa_display.waveplot(data, sr=sr, alpha=0.5)
librosa_display.waveplot(augmented_data, sr=sr, color='r', alpha=0.25)

plt.tight_layout()
plt.show()
# Out:
# Warning: noise_factor will be removed after 0.0.12 release. Change to use

# %%
ipd.Audio(augmented_data, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Pitch augmenter

# %%
aug = naa.PitchAug(sampling_rate=sr, pitch_factor=(2,3))
augmented_data = aug.augment(data)

librosa_display.waveplot(data, sr=sr, alpha=0.5)
librosa_display.waveplot(augmented_data, sr=sr, color='r', alpha=0.25)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-92d78d3364cf> in <module>()
# ----> 1 aug = naa.PitchAug(sampling_rate=sr, pitch_factor=(2,3))
#       2 augmented_data = aug.augment(data)
#       3
#       4 librosa_display.waveplot(data, sr=sr, alpha=0.5)
#       5 librosa_display.waveplot(augmented_data, sr=sr, color='r', alpha=0.25)
#
# TypeError: __init__() got an unexpected keyword argument 'pitch_factor'

# %% [markdown]
# ### Shift augmenter

# %%
aug = naa.ShiftAug(sampling_rate=sr)
augmented_data = aug.augment(data)

librosa_display.waveplot(data, sr=sr, alpha=0.5)
librosa_display.waveplot(augmented_data, sr=sr, color='r', alpha=0.25)

plt.tight_layout()
plt.show()

# %%
ipd.Audio(augmented_data, rate=sr)
# Out:
# /Users/kakao/anaconda/anaconda/lib/python3.6/site-packages/IPython/lib/display.py:135: RuntimeWarning: invalid value encountered in true_divide
#   scaled = np.int16(data/np.max(np.abs(data))*32767).tolist()
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Speed Augmenter

# %%
aug = naa.SpeedAug()
augmented_data = aug.augment(data)

librosa_display.waveplot(data, sr=sr, alpha=0.5)
librosa_display.waveplot(augmented_data, sr=sr, color='r', alpha=0.25)

plt.tight_layout()
plt.show()

# %%
ipd.Audio(augmented_data, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### vtlp

# %%
aug = naa.VtlpAug(sampling_rate=sr)
augmented_data = aug.augment(data)

# %%
ipd.Audio(augmented_data, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
